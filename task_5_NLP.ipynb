# %% [markdown]
# <a href="https://colab.research.google.com/github/Sravan25879/APS-JAVA-LEETCODE/blob/main/task_5_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string
import random
import nltk
from nltk.corpus import stopwords, reuters
from collections import Counter, defaultdict
from nltk import FreqDist, ngrams

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('reuters')
nltk.download('punkt_tab') # Added to resolve ValueError: No sentence tokenizer for this corpus

sents = reuters.sents()

stop_word = set(stopwords.words('english'))

string.punctuation = string.punctuation + ' " ' + ' " ' + ' - ' + ' _ '

removal_list = list(stop_word) + list(string.punctuation) + ['\t', 'rt']

unigram = []
bigram = []
trigram = []
tokenized_text = []

for sentence in sents:
    sentence = list(map(lambda x: x.lower(), sentence))

    for word in sentence:
        if word == '.':
            sentence.remove(word)
        else:
            unigram.append(word)

    tokenized_text.append(word)

    bigram.extend(list(ngrams(sentence, 2,
                               pad_left=True, pad_right=True)))

    trigram.extend(list(ngrams(sentence, 3,
                                pad_left=True, pad_right=True)))


def remove_stopwords(x):
    y = []

    for pair in x:
        count = 0

        for word in pair:
            if word in removal_list:
                count = count or 0
            else:
                count = count or 1

        if count == 1:
            y.append(pair)

    return y


unigram = remove_stopwords(unigram)
bigram = remove_stopwords(bigram)
trigram = remove_stopwords(trigram)

freq_uni = FreqDist(unigram)
freq_bi = FreqDist(bigram)
freq_tri = FreqDist(trigram)

d = defaultdict(Counter)

for a, b, c in freq_tri:
    if (a is not None) and (b is not None) and (c is not None):
        d[a, b][c] += freq_tri[a, b, c]


def pick_word(counter):
    """Choose a random element with weighted probability."""
    words = list(counter.keys())
    counts = list(counter.values())
    return random.choices(words, weights=counts, k=1)[0]


prefix = "he", "is"

print(" ".join(prefix))

s = " ".join(prefix)

for i in range(19):
    suffix = pick_word(d[prefix])
    s = s + " " + suffix
    print(s)
    prefix = prefix[1], suffix
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# he is
# he is forecasting
# he is forecasting fiscal
# he is forecasting fiscal 1988
# he is forecasting fiscal 1988 earnings
# he is forecasting fiscal 1988 earnings could
# he is forecasting fiscal 1988 earnings could be
# he is forecasting fiscal 1988 earnings could be about
# he is forecasting fiscal 1988 earnings could be about 1
# he is forecasting fiscal 1988 earnings could be about 1 85
# he is forecasting fiscal 1988 earnings could be about 1 85 dlrs
# ...
